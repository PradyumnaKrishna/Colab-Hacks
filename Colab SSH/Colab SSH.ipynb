# %% [markdown]
# <a href="https://colab.research.google.com/github/PradyumnaKrishna/Colab-Hacks/blob/Agro/Colab%20SSH/Colab%20SSH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Colab SSH** : SSH to Colab Instance (Deprecated)
#
# **This notebook is now deprecated use [Colab RDP](https://colab.research.google.com/github/PradyumnaKrishna/Colab-Hacks/blob/master/Colab%20RDP/Colab%20RDP.ipynb) notebook instead**
#
# - **NGROK has some problems with colab**
# - Use Agro
#
# There are Two methods of doing same thing :
#  - Using colab_ssh pip library
#  - Manually configuring SSHD
#
# Run command on your Local Computer to connect using SSH
#
#     ssh root@0.tcp.ngrok.io -p <givenport>
#
# And then enter the password

# %% [markdown]
# # Using **colab_ssh** Library

# %% [markdown]
# ### Installing colab_ssh Library

# %%
# !pip install colab_ssh --upgrade

# %% [markdown]
# ### Generate Root Password

# %%
import random, string
password = ''.join(random.choice(string.ascii_letters + string.digits) for i in range(20))

# %% [markdown]
# ### Launch SSH with Ngrok

# %%
print("Copy authtoken from https://dashboard.ngrok.com/auth")
ngrokToken = input("Enter Token : ")

from colab_ssh import launch_ssh, init_git
launch_ssh(ngrokToken, password)

# Get Public Address
print("This notebook is now deprecated use Colab RDP notebook instead")

print("Run command : ssh root@", end='')
# !curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'][6:].replace(':', ' -p '))"

# Print Password
print("Password : ", password)

# %% [markdown]
# ### Launch SSH with Agro

# %%
from colab_ssh import launch_ssh_cloudflared
launch_ssh_cloudflared(password=password)

print("Password : ", password)

# %% [markdown]
# # Manually configuring SSHD

# %% [markdown]
# ### Generate root password

# %%
import random, string
password = ''.join(random.choice(string.ascii_letters + string.digits) for i in range(20))

# %% [markdown]
# ### Download ngrok

# %%
# !wget -q -c -nc https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip -qq -n ngrok-stable-linux-amd64.zip

# %% [markdown]
# ### Setup sshd

# %%
# !apt-get install -qq -o=Dpkg::Use-Pty=0 openssh-server pwgen > /dev/null

# %% [markdown]
# ### Set root password

# %%
! echo root:$password | chpasswd
! mkdir -p /var/run/sshd
! echo "PermitRootLogin yes" >> /etc/ssh/sshd_config
! echo "PasswordAuthentication yes" >> /etc/ssh/sshd_config
! echo "LD_LIBRARY_PATH=/usr/lib64-nvidia" >> /root/.bashrc
! echo "export LD_LIBRARY_PATH" >> /root/.bashrc

# %% [markdown]
# ### Run sshd

# %%
get_ipython().system_raw('/usr/sbin/sshd -D &')

# %% [markdown]
# ### Ask token

# %%
print("Copy authtoken from https://dashboard.ngrok.com/auth")
import getpass
authtoken = getpass.getpass()

# %% [markdown]
# ### Create tunnel

# %%
get_ipython().system_raw('./ngrok authtoken $authtoken && ./ngrok tcp 22 &')

# %% [markdown]
# ### Print root password

# %%
print("Root password: {}".format(password))

# %% [markdown]
# ### Get public address

# %%
# Get Public Address
print("This notebook is now deprecated use Colab RDP notebook instead")

print("Run command : ssh root@", end='')
# !curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'][6:].replace(':', ' -p '))"

# Print Password
print("Password : ", password)
